# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("lenna.png")

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("Leena.png")

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[16], line 6
#       2 import matplotlib.pyplot as plt
#       4 img = cv2.imread("Leena.png")
# ----> 6 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       8 plt.imshow(img_rgb)
#       9 plt.title("Original Image")
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import os
import matplotlib.pyplot as plt

print("Current folder:")
print(os.getcwd())

print("\nFiles in current folder:")
print(os.listdir())

img = cv2.imread("Leena.png")

print("\nImage loaded:", img is not None)

if img is None:
    print("❌ Leena.png was NOT found/read.")
else:
    print("✅ Image loaded successfully!")
    print("Image shape:", img.shape)

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)
    plt.title("Original Image")
    plt.axis("off")
    plt.show()
# Out:
# Current folder:
# C:\Users\sarna\Desktop\STUDY\Image Processing\Day 3
#
# Files in current folder:
# ['.ipynb_checkpoints', 'lenna.png', 'Untitled.ipynb']
#
# Image loaded: False
# ❌ Leena.png was NOT found/read.
